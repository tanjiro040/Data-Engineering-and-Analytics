# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to print single line text message

print("Welcome to Python Programming")
# Out:
# Welcome to Python Programming

# %%
# Program to print a multi-line text message

print("Hello!!\nGood Afternoon !\nWelcome to AI Lab")
# Out:
# Hello!!
# Good Afternoon !
# Welcome to AI Lab

# %%
# Datatypes (various types of data recognised by python programming language)
# declaration of variables (Variable- named memory location which stores data)

# INTEGER type variable

a=5
b=5
print(a+b)
type(a)


# CHARACTER type variable

ch='5'
type(ch)
print(ch)
print(int(ch))

# FLOAT type variable

d= 5.2
type(d)
print(int(d))
# Out:
# 10
# 5
# 5
# 5

# %%
# CHARACTER type variable

ch='5'
#type(ch)
#print(ch)
print(int(ch))
# Out:
# 5

# %%
# Declaring and displaying a string

name="XYZ"
print(name)

# %%
# To add a integer with a decimal number (float type variable)

a=7
b=4.5
c= a+b
print("Addition of a & b is",c)           #displaying result as a decimal number
print("Addition of a & b is",int(c))      #displaying result as an integer
# Out:
# Addition of a & b is 11.5
# Addition of a & b is 11

# %%
# Boolean type variable

s =True
print(s)
type(s)
# Out:
# True
# bool

# %%
a=10
print(a==10)
# Out:
# True

# %%
# INPUT statement to accept data as input from the user

name= input("Please enter your name")
print(name)
print("Hello", name,"\nGood Day\nWelcome to Python Programming")
# Out:
# Please enter your nameMonika
# Monika
# Hello Monika
# Good Day
# Welcome to Python Programming

# %%
# Program to accept two real(decimal) numbers as input
# add them and display the output

a = float(input("Please enter the first number"))
b = float(input("Please enter the second number"))
c=a+b
print("addition is",c)
# Out:
# Please enter the first number4.5
# Please enter the second number2
# addition is 6.5

# %%
# Program to find the greatest of two numbers

a = float(input("Please enter the first number"))
b = float(input("Please enter the second number"))

if a>b:
  print(a,"is greater than",b)
  print(a)
elif b>a:
  print(b,"is greater than",a)
  print(b)
else:
  print(a,"is equal to",b)
# Out:
# Please enter the first number4
# Please enter the second number4
# 4.0 is equal to 4.0

# %%
# Program to swap two numbers (using third variable)

a=3
b=2
print("a=",a)
print("b=",b)
c=a
a=b
b=c
print("a=",a)
print("b=",b)
# Out:
# a= 3
# b= 2
# a= 2
# b= 3

# %%
# Program to swap two numbers (without using third variable)

a=3
b=2
print("a=",a)
print("b=",b)
(a,b)=(b,a)
print("a=",a)
print("b=",b)
