# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# creating dataframe from the given datasheet by using dataframe () funct95,ion in pandas
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
print(STUDENT_DATA)
# Out:
#   student name  physics  chemistry  maths
# 0         aman       78         80     88
# 1        rahul       67         77     95
# 2       shreya       85         85    100
# 3       vinita       96         90     90

# %%
# reading data (certain no of rows and column) from a database using locate rows.loc,iloc
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
print(STUDENT_DATA.loc[[2]])
# Out:
#   student name  physics  chemistry  maths
# 2       shreya       85         85    100

# %%
# reading data (certain no of rows and column) from a database using locate rows.loc,iloc
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
print(STUDENT_DATA.iloc[[1]])
# Out:
#   student name  physics  chemistry  maths
# 1        rahul       67         77     95

# %%
#adding name to each row using index
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata,index=['student1','student2','student3','student4'])
print(STUDENT_DATA.to_string())
# Out:
#          student name  physics  chemistry  maths
# student1         aman       78         80     88
# student2        rahul       67         77     95
# student3       shreya       85         85    100
# student4       vinita       96         90     90

# %%
#to access the data of a row using row index name
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata,index=['student1','student2','student3','student4'])
print(STUDENT_DATA.to_string())
print(STUDENT_DATA.loc[['student1']])
# Out:
#          student name  physics  chemistry  maths
# student1         aman       78         80     88
# student2        rahul       67         77     95
# student3       shreya       85         85    100
# student4       vinita       96         90     90
#          student name  physics  chemistry  maths
# student1         aman       78         80     88

# %%
#to access the data of a student by specifyimg 'student name '
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
STUDENT_DATA=STUDENT_DATA.set_index(['student name'])
print(STUDENT_DATA.loc[['rahul']])
# Out:
#               physics  chemistry  maths
# student name
# rahul              67         77     95

# %%
#determining the shape  (rows and column)of database using size function
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
print("(rows and column) in the given data is",STUDENT_DATA.shape)
# Out:
# (rows and column) in the given data is (4, 4)

# %%
#determining the size (rows and column)of database using size function
import pandas as pd
studentdata={'student name':['aman','rahul','shreya','vinita'],'physics':[78,67,85,96],'chemistry':[80,77,85,90],'maths':[88,95,100,90]}
STUDENT_DATA=pd.DataFrame(studentdata)
print("no of elements in the given data set",STUDENT_DATA.size)
# Out:
# no of elements in the given data set 16

# %%
#reading student data from .xls
import pandas as pd
STUDENT_DATA=pd.read_excel("StudentDataSet1_LAB2.xlsx")
print(STUDENT_DATA)
# Out:
#   Student Name  Physics   Chemistry  Maths
# 0         Aman       78          80     88
# 1        Rahul       67          77     95
# 2       Shreya       85          85    100
# 3       Vinita       96          90     90

# %%
#reading student data from .csv
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
print(STUDENT_DATA)
# Out:
#   Student Name  Physics  Chemistry  Maths
# 0         Aman       78         80     88
# 1        Rahul       67         77     95
# 2       Shreya       85         85    100
# 3       Vinita       96         90     90

# %%
#reading student data from json
import pandas as pd
STUDENT_DATA=pd.read_json("StudentDataSet1_LAB2.json")
print(STUDENT_DATA)
# Out:
#   Student Names  Physics  Chemistry  Maths
# 0          Aman       78         80     88
# 1         Rahul       67         77     95
# 2        Shreya       85         85    100
# 3        Vinita       96         90     90

# %%
#displaying first few rows of a darframe using a head function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
print(STUDENT_DATA.head(2))
# Out:
#   Student Name  Physics  Chemistry  Maths
# 0         Aman       78         80     88
# 1        Rahul       67         77     95

# %%
#displaying last few rows of a dataframe using tail function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
print(STUDENT_DATA.tail(2))
# Out:
#   Student Name  Physics  Chemistry  Maths
# 1        Rahul       67         77     95
# 2       Shreya       85         85    100
# 3       Vinita       96         90     90

# %%
#displaying info about the type of data in a dataframe using info function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
print(STUDENT_DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  4 non-null      object
#  1   Physics       4 non-null      int64
#  2   Chemistry     4 non-null      int64
#  3   Maths         4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes
# None

# %%
#display column names
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
print(STUDENT_DATA.columns)
# Out:
# Index(['Student Name', 'Physics', 'Chemistry', 'Maths'], dtype='object')

# %%
#to add a new column using insert function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
STUDENT_DATA.insert(4,'English',[96,75,88,80],True)
print(STUDENT_DATA)
# Out:
#   Student Name  Physics  Chemistry  Maths  English
# 0         Aman       78         80     88       96
# 1        Rahul       67         77     95       75
# 2       Shreya       85         85    100       88
# 3       Vinita       96         90     90       80

# %%
#to add a new column WITHOUT using insert function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
English=[96,75,88,80]
STUDENT_DATA['English']=English
print(STUDENT_DATA)
# Out:
#   Student Name  Physics  Chemistry  Maths  English
# 0         Aman       78         80     88       96
# 1        Rahul       67         77     95       75
# 2       Shreya       85         85    100       88
# 3       Vinita       96         90     90       80

# %%
#to add a new row using loc function
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
STUDENT_DATA.loc[4]=['Vishal',96,75,88]
print(STUDENT_DATA)
# Out:
#   Student Name  Physics  Chemistry  Maths
# 0         Aman       78         80     88
# 1        Rahul       67         77     95
# 2       Shreya       85         85    100
# 3       Vinita       96         90     90
# 4       Vishal       96         75     88

# %%
#concatenation of two dataframe using concat function
studentdata1={'student name':['aman','rahul','shreya'],'physics':[78,67,85],'chemistry':[80,77,85],'maths':[88,95,100]}
studentdata2={'student name':['vinita','vishal'],'physics':[96,88],'chemistry':[90,97],'maths':[90,100]}
STUDENT_DATA1=pd.DataFrame(studentdata1)
STUDENT_DATA2=pd.DataFrame(studentdata2)
STUDENT_DATA=pd.concat([STUDENT_DATA1,STUDENT_DATA2],ignore_index=True)
print(STUDENT_DATA)
# Out:
#   student name  physics  chemistry  maths
# 0         aman       78         80     88
# 1        rahul       67         77     95
# 2       shreya       85         85    100
# 3       vinita       96         90     90
# 4       vishal       88         97    100

# %%
#to evaluate percentage and display it
import pandas as pd
STUDENT_DATA=pd.read_csv("StudentDataSet1_LAB2.csv")
Percentage=(STUDENT_DATA.iloc[:,1:4].sum(axis=1))/3
STUDENT_DATA['Percentage']=Percentage
print(STUDENT_DATA)
# Out:
#   Student Name  Physics  Chemistry  Maths  Percentage
# 0         Aman       78         80     88   82.000000
# 1        Rahul       67         77     95   79.666667
# 2       Shreya       85         85    100   90.000000
# 3       Vinita       96         90     90   92.000000
