# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/Lab_1_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To accept the 'name' of the user and print welcome message.
A=input("Enter the name:")
print("Hello!",A)
print("Welcome!!")
# Out:
# Enter the name:kanchan sharma
# Hello! kanchan sharma
# Welcome!!

# %%
#To accept real(decimal)number from the user and print their addition.
A=float(input("Value of num1="))
B=float(input("Value of num2="))
C=A+B
print ("The sum of num1 and num2=",C)
# Out:
# Value of num1=6.6
# Value of num2=4.5
# The sum of num1 and num2= 11.1

# %%
#temperature
T=float(input("current temperature="))
if T>27:
  print("weather is HOT")
elif T==27:
  print("weather is COMFORTABLE")
else:
  print("weather is COLD")
# Out:
# current temperature=24.5
# weather is COLD

# %%
#simple calculator

# %%
print("simple calculator")
print("1.Addition")
print("2.Sbtraction")
print("3.Multiply")
print("4.divide")
op=int(input("select operation 1/2/3/4:"))
x=int(input("Enter the value of x="))
y=int(input("Enter the value of y="))
a=x+y
b=x-y
c=x*y
d=x/y
if op==1:
  print("sum",a)
if op==2:
  print("fifference:",b)
if op==3:
  print("product:",c)
if op==4:
  print("quotient:",d)
# Out:
# simple calculator
# 1.Addition
# 2.Sbtraction
# 3.Multiply
# 4.divide
# select operation 1/2/3/4:4
# Enter the value of x=43
# Enter the value of y=5
# quotient: 8.6

# %%
#greatest integer
a=int(input("num1="))
b=int(input("num2="))
c=int(input("num3="))
if a>b:
  print("a is the greatest integer")
elif b>c:
  print("b is the greatest integer")
else:
  print("c is the greatest integer")
# Out:
# num1=4
# num2=7
# num3=8
# c is the greatest integer

# %%
#swap
a=float(input("num1:"))
b=float(input("num2:"))
a,b=b,a
print("num:",a,b)
# Out:
# num1:6
# num2:9
# num: 9.0 6.0

# %%
#even/odd
a=float(input("Enter the number:"))
if a%2==0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter the number:10
# The number is even

# %%
#Quadratic equation
a=int(input("Enter the value of a="))
b=int(input("Enter the value of b="))
c=int(input("Enter the value of c="))
d=(b**2)-(4*a*c)
e=((-b)+(d**(1/2)))/(2*a)
f=((-b)-(d**(1/2)))/(2*a)
print("The roots are",e,"and",f)
# Out:
# Enter the value of a=5
# Enter the value of b=7
# Enter the value of c=8
# The roots are (-0.7+1.0535653752852738j) and (-0.7000000000000001-1.0535653752852738j)
