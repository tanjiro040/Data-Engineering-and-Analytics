# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')

print(Calories)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.count())
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    30
# dtype: int64
# Duration     68.4375
# Pulse       103.5000
# Maxpulse    128.5000
# Calories    304.6800
# dtype: float64
# <ipython-input-2-6739750feea4>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.mean())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.mean())
# Out:
# Duration     68.4375
# Pulse       103.5000
# Maxpulse    128.5000
# Calories    304.6800
# dtype: float64
# <ipython-input-3-e00fdfab0700>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.mean())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.min())
# Out:
# Duration     30.0
# Pulse        90.0
# Maxpulse    101.0
# Calories    195.1
# dtype: float64
# <ipython-input-4-df28aaf766f9>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.min())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.max())
# Out:
# Duration    450.0
# Pulse       130.0
# Maxpulse    175.0
# Calories    479.0
# dtype: float64
# <ipython-input-5-aadf9c5a25fb>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.max())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.std())
# Out:
# Duration    70.039591
# Pulse        7.832933
# Maxpulse    12.998759
# Calories    66.003779
# dtype: float64
# <ipython-input-6-110ddade851c>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.std())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.mode())
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/12'    100       120     300.0

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.median())
# Out:
# Duration     60.0
# Pulse       102.5
# Maxpulse    127.5
# Calories    291.2
# dtype: float64
# <ipython-input-9-314e48cc02c8>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(Calories.median())

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories.describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
Calories_clean = Calories.dropna()
print(Calories_clean)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
Calories["Date"].fillna("'2020/12/31'",inplace=True)
Calories["Calories"].fillna(100,inplace=True)
print(Calories)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
Calories_clean = Calories.isnull()
print(Calories_clean)
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
print(Calories_clean)
Calories_clean = Calories.duplicated().sum()
print("No of duplicate entries:",Calories_clean)
Calories_clean = Calories.drop_duplicates()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
# No of duplicate entries: 1
# No of duplicate entries:     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# ...

# %%
import pandas as pd
Calories = pd.read_csv('CaloriesDataSet.csv')
Calories_clean = Calories.duplicated()
print(Calories_clean)
Calories_clean = Calories.corr()
print("No of duplicate entries:",Calories_clean)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
# No of duplicate entries:           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000  0.004410  0.049959 -0.114169
# Pulse     0.004410  1.000000  0.276583  0.513186
# Maxpulse  0.049959  0.276583  1.000000  0.357460
# Calories -0.114169  0.513186  0.357460  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories["Pulse"].plot(kind="hist")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories.head(10).plot(kind='bar',x='Pulse')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories = pd.read_csv('CaloriesDataSet.csv')
Calories.head(10).plot(kind='bar',x='Pulse')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(Calories['Maxpulse'].head(20))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(Calories.corr(),annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories.agg(['sum','min','max'])
# Out:
#      Duration  Pulse  Maxpulse  Calories
# sum      2190   3312      4112    9140.4
# min        30     90       101     195.1
# max       450    130       175     479.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories.groupby('Duration').agg(['sum','mean','median','min','max','prod'])
# Out:
#          Pulse                                         Maxpulse              \
#            sum     mean median  min  max          prod      sum        mean
# Duration
# 30         109  109.000  109.0  109  109  1.090000e+02      133  133.000000
# 45         618  103.000  102.5   90  117  1.169004e+12      811  135.166667
# 60        2481  103.375  102.0   92  130  2.084879e+48     3034  126.416667
# 450        104  104.000  104.0  104  104  1.040000e+02      134  134.000000
#
#                                         Calories                           \
#          median  min  max          prod      sum       mean median    min
# Duration
# 30        133.0  133  133  1.330000e+02    195.1  195.10000  195.1  195.1
# 45        128.5  112  175  5.695721e+12   1459.4  291.88000  282.0  243.0
# 60        126.5  101  147  2.591241e+50   7232.6  314.46087  300.0  215.2
# 450       134.0  134  134  1.340000e+02    253.3  253.30000  253.3  253.3
#
#
#             max          prod
# ...

# %% [markdown]
# Housing

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')

print(Data)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.count())
print(Data)
# Out:
# CRIM       486
# ZN         486
# INDUS      486
# CHAS       486
# NOX        506
# RM         506
# AGE        486
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      486
# MEDV       506
# dtype: int64
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# ...

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.mean())
# Out:
# CRIM         3.611874
# ZN          11.211934
# INDUS       11.083992
# CHAS         0.069959
# NOX          0.554695
# RM           6.284634
# AGE         68.518519
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.715432
# MEDV        22.532806
# dtype: float64

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.min())
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# MEDV         5.00000
# dtype: float64

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.mode())
# Out:
#        CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0   0.01501  0.0   18.1   0.0  0.538  5.713  100.0  3.4952  24.0  666.0
# 1  14.33370  NaN    NaN   NaN    NaN  6.127    NaN     NaN   NaN    NaN
# 2       NaN  NaN    NaN   NaN    NaN  6.167    NaN     NaN   NaN    NaN
# 3       NaN  NaN    NaN   NaN    NaN  6.229    NaN     NaN   NaN    NaN
# 4       NaN  NaN    NaN   NaN    NaN  6.405    NaN     NaN   NaN    NaN
# 5       NaN  NaN    NaN   NaN    NaN  6.417    NaN     NaN   NaN    NaN
#
#    PTRATIO      B  LSTAT  MEDV
# 0     20.2  396.9   6.36  50.0
# 1      NaN    NaN   7.79   NaN
# 2      NaN    NaN   8.05   NaN
# 3      NaN    NaN  14.10   NaN
# 4      NaN    NaN  18.13   NaN
# 5      NaN    NaN    NaN   NaN

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.median())
# Out:
# CRIM         0.253715
# ZN           0.000000
# INDUS        9.690000
# CHAS         0.000000
# NOX          0.538000
# RM           6.208500
# AGE         76.800000
# DIS          3.207450
# RAD          5.000000
# TAX        330.000000
# PTRATIO     19.050000
# B          391.440000
# LSTAT       11.430000
# MEDV        21.200000
# dtype: float64

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.std())
# Out:
# CRIM         8.720192
# ZN          23.388876
# INDUS        6.835896
# CHAS         0.255340
# NOX          0.115878
# RM           0.702617
# AGE         27.999513
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.155871
# MEDV         9.197104
# dtype: float64

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
print(Data.describe())
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
Data_clean = Data.dropna()
print(Data_clean)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
import pandas as pd
Data = pd.read_csv('HousingPrice-DataSet.csv')
Data["CRIM"].fillna("0.0",inplace=True)
Data["ZN"].fillna("0.0",inplace=True)
Data["INDUS"].fillna("0.0",inplace=True)
Data["CHAS"].fillna("0.0",inplace=True)
Data["NOX"].fillna("0.0",inplace=True)
Data["RM"].fillna("0.0",inplace=True)
Data["AGE"].fillna("0.0",inplace=True)
Data["RAD"].fillna("0.0",inplace=True)
Data["PTRATIO"].fillna("0.0",inplace=True)
Data["LSTAT"].fillna("0.0",inplace=True)
Data["MEDV"].fillna("0.0",inplace=True)
print(Data)
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31  0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07  0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18  0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18  0.0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93  0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93  0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93  0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93  0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93  0.0  0.573  6.030   0.0  2.5050    1  273     21.0
#
#           B LSTAT  MEDV
# ...

# %%
import pandas as pd
Data_clean = Data.isnull().sum()
print(Data_clean)
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
import pandas as pd




Data_clean = Data.duplicated().sum()
print("No of duplicate entries:",Data_clean)
Data_clean = Data.drop_duplicates()
# Out:
# No of duplicate entries: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Data["TAX"].plot(kind="hist")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories = pd.read_csv('HousingPrice-DataSet.csv')
Calories.head(30).plot(kind='bar',x='AGE')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(Data['TAX'].head(50))
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(Data.corr(),annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Data.agg(['sum','min','max'])
# Out:
#           NOX        RM        DIS   RAD     TAX  PTRATIO          B     MEDV
# sum  280.6757  3180.025  1920.2916  4832  206568   9338.5  180477.06  11401.6
# min    0.3850     3.561     1.1296     1     187     12.6       0.32      5.0
# max    0.8710     8.780    12.1265    24     711     22.0     396.90     50.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Calories.groupby('TAX').agg(['sum','mean','median','min','max','prod'])
# Out:
#            CRIM                                                           ZN  \
#             sum       mean    median      min       max           prod   sum
# TAX
# 187     0.01709   0.017090  0.017090  0.01709   0.01709   1.709000e-02  90.0
# 188     1.03887   0.148410  0.098490  0.06899   0.38735   4.457204e-07   0.0
# 193     0.48316   0.069023  0.065880  0.05602   0.09103   6.719527e-09   0.0
# 198     0.01501   0.015010  0.015010  0.01501   0.01501   1.501000e-02  90.0
# 216     0.36401   0.072802  0.037050  0.01951   0.21038   3.334878e-07  97.5
# ..          ...        ...       ...      ...       ...            ...   ...
# 432     1.14646   0.143308  0.136945  0.10084   0.22212   1.475769e-07   0.0
# 437     8.84148   0.589432  0.352330  0.24980   1.62864   2.340341e-05   0.0
# 469     0.01360   0.013600  0.013600  0.01360   0.01360   1.360000e-02  75.0
# 666  1613.39850  13.011278  9.209660  2.37857  88.97620  1.538223e+122   0.0
# ...
