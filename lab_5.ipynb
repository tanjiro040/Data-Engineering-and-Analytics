# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#A.1.display the column names and the number of records/column
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
print(Employee_data.info())
COL=Employee_data.columns
for x in COL:
  print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EMP ID      8 non-null      int64
#  1   EMP NAME    8 non-null      object
#  2   SALARY      6 non-null      float64
#  3   START DATE  8 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 384.0+ bytes
# None
# EMP ID
# EMP NAME
# SALARY
# START DATE

# %%
2.#display the first 4 records of the database
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
print(Employee_data.head(4))
# Out:
#    EMP ID EMP NAME    SALARY  START DATE
# 0       1   Satish   50000.0  01-11-2017
# 1       2    Reeya   75000.0  12-05-2016
# 2       3      Jay  100000.0  22-09-2015
# 3       4    Rahul       NaN  11-10-2016

# %%
3.#evaluate various statistical parameters using described () function
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
print(Employee_data.describe())
# Out:
#         EMP ID         SALARY
# count  8.00000       6.000000
# mean   4.50000   70833.333333
# std    2.44949   24782.386218
# min    1.00000   45000.000000
# 25%    2.75000   51250.000000
# 50%    4.50000   65000.000000
# 75%    6.25000   93750.000000
# max    8.00000  100000.000000

# %%
4.#check for the missing values in the dataset
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
Employee_data.isnull()
# Out:
#    EMP ID  EMP NAME  SALARY  START DATE
# 0   False     False   False       False
# 1   False     False   False       False
# 2   False     False   False       False
# 3   False     False    True       False
# 4   False     False   False       False
# 5   False     False   False       False
# 6   False     False    True       False
# 7   False     False   False       False

# %%
5.#check for the missing values in the dataset and replace them with some valid numeric value
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
Employee_data['SALARY'].fillna(40000,inplace=True)
print(Employee_data)
# Out:
#    EMP ID EMP NAME    SALARY  START DATE
# 0       1   Satish   50000.0  01-11-2017
# 1       2    Reeya   75000.0  12-05-2016
# 2       3      Jay  100000.0  22-09-2015
# 3       4    Rahul   40000.0  11-10-2016
# 4       5      Roy   45000.0  08-01-2017
# 5       6      Jay  100000.0  22-09-2015
# 6       7   Vishal   40000.0  05-01-2016
# 7       8    Serah   55000.0  06-02-2018

# %%
6.#find duplicate recordsin the dataset
import pandas as pd
Employee_data=pd.read_csv("/content/EMP-DataSet.csv")
print(Employee_data.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
#THERE IS NO DUPLICATE VALUE IN THE DATASET

# %%
#B.1.Number of rows and column and column name
import pandas as pd
Patient_data=pd.read_csv("/content/diabetes.csv")
print(Patient_data.info())
COL=Patient_data.columns
for x in COL:
  print(x)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age
# Outcome

# %%
2.#Display first 10 records of the dataset
import pandas as pd
Patient_data=pd.read_csv("/content/diabetes.csv")
print(Patient_data.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
3.#statistical parameters using describe () function
import pandas as pd
Patient_data=pd.read_csv("/content/diabetes.csv")
print(Patient_data.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
4.#Finding and removing duplicate values
import pandas as pd
Patient_data=pd.read_csv("/content/diabetes.csv")
print(Patient_data.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
#IT DOES NOT CONTAIN ANY DUPLICATE VALUE

# %%
5.#presence of missing value in the dataset
import pandas as pd
Patient_data=pd.read_csv("/content/diabetes.csv")
Patient_data.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
# IT DOES NOT CONTAIN ANY NULL VALUE

# %%
6.# show scatter plot depicting relationship between two numeric columns of your choice
import pandas as pd
import matplotlib.pyplot as plt
Patient_data=pd.read_csv("/content/diabetes.csv")
Patient_data.plot(kind='scatter',x='Age',y='BMI',marker='X')
plt.show()
