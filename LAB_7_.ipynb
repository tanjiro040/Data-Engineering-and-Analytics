# %% [markdown]
# <a href="https://colab.research.google.com/github/tanjiro040/Data-Engineering-and-Analytics/blob/main/LAB_7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Reading Time-series data into Pandas dataframe
import pandas as pd
PassengerData = pd.read_csv('/content/AirPassengers.csv')
PassengerData.columns=['Date (yyyy-mm)','Number of Passengers']
PassengerData.head(21)
# Out:
#    Date (yyyy-mm)  Number of Passengers
# 0         1949-01                   112
# 1         1949-02                   118
# 2         1949-03                   132
# 3         1949-04                   129
# 4         1949-05                   121
# 5         1949-06                   135
# 6         1949-07                   148
# 7         1949-08                   148
# 8         1949-09                   136
# 9         1949-10                   119
# 10        1949-11                   104
# 11        1949-12                   118
# 12        1950-01                   115
# 13        1950-02                   126
# 14        1950-03                   141
# 15        1950-04                   135
# 16        1950-05                   125
# 17        1950-06                   149
# 18        1950-07                   170
# 19        1950-08                   170
# 20        1950-09                   158

# %%
#PLOTTING TIME-SERIES DATA using plot() function
import pandas as pd
import matplotlib.pyplot as plt
PassengerData = pd.read_csv('/content/AirPassengers.csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.plot(x='Date(yyyy-mm)', y='Number of Passengers')

title=('Number of US Airline passengers from 1949 to 1960')

plt.ylabel('Number of Passengers')
plt.show()

# %%
#ETS Decomposition-MULTIPLICATIVE MODEL
#Extracting TREND component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
multiplicative_decomposition = sm(PassengerData['Number of Passengers'], model='multiplicative', period=12)
multiplicative_decomposition.trend.plot()
plt.ylabel('Number of Passengers (TREND)')
plt.grid()

# %%
#Extracting SEASONAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
multiplicative_decomposition = sm(PassengerData['Number of Passengers'], model='multiplicative', period=12)
multiplicative_decomposition.seasonal.plot()
plt.ylabel('Number of Passengers (SEASONAL)')
plt.grid()

# %%
#Extracting RESIDUAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
multiplicative_decomposition = sm(PassengerData['Number of Passengers'], model='multiplicative', period=12)
multiplicative_decomposition.resid.plot()
plt.ylabel('Number of Passengers (RANDOM FLUCTUATION (NOISE))')
plt.grid()

# %%
#ETS Decomposition-ADDITIVE MODEL
#Extracting TREND component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
Additive_decomposition = sm(PassengerData['Number of Passengers'], model='additive', period=12)
Additive_decomposition.trend.plot()
plt.ylabel('Number of Passengers (TREND)')
plt.show()

# %%
#Extracting SEASONAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
Additive_decomposition = sm(PassengerData['Number of Passengers'],model='additive', period=12)
Additive_decomposition.seasonal.plot()
plt.ylabel('Number of Passengers (SEASONAL)')
plt.show()

# %%
#Extracting RESIDUAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
PassengerData = pd.read_csv('/content/AirPassengers(1).csv')
PassengerData.columns=['Date(yyyy-mm)','Number of Passengers']
PassengerData.set_index('Date(yyyy-mm)',inplace=True)
Additive_decomposition = sm(PassengerData['Number of Passengers'], model='additive', period=12)
Additive_decomposition.resid.plot()
plt.grid()
plt.show()

# %%
#SuperStore-SalesDataSet
#Reading Time-series data into Pandas dataframe
import pandas as pd
PassengerData = pd.read_csv('/content/SuperStore-SalesDataSet.csv')
PassengerData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
PassengerData.head()
pd.options.display.max_rows = 999

df = pd.read_csv('/content/SuperStore-SalesDataSet.csv')

print(df)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#PLOTTING TIME-SERIES DATA using plot() function
import pandas as pd
import matplotlib.pyplot as plt
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet.csv')
PassengerData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
PassengerData.plot(x='State', y='Sales')

title=('SuperStore-Sales Data')

plt.ylabel('Sales')
plt.show()

# %%
#ETS Decomposition-MULTIPLICATIVE MODEL
#Extracting TREND component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet.csv')
StoreData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
StoreData.set_index('Category',inplace=True)
multiplicative_decomposition = sm(StoreData['Sales'], model='multiplicative', period=12)
multiplicative_decomposition.trend.plot()
plt.ylabel('Category(TREND)')
plt.grid()

# %%
#Extracting RESIDUAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet (1).csv')
StoreData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
StoreData.set_index('Region',inplace=True)
multiplicative_decomposition = sm(StoreData['Sales'], model='multiplicative', period=12)
multiplicative_decomposition.resid.plot()
plt.ylabel('Region((RANDOM FLUCTUATION (NOISE))')
plt.grid()

# %%
#ETS Decomposition-ADDITIVE MODEL
#Extracting TREND component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet (1).csv')
StoreData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
StoreData.set_index('Order Date(yyyy-mm)',inplace=True)
Additive_decomposition = sm(StoreData['Sales'], model='additive', period=12)
Additive_decomposition.trend.plot()
plt.ylabel('Order Date(yyyy-mm)(TREND)')
plt.show()

# %%
#Extracting SEASONAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet (1).csv')
StoreData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
StoreData.set_index('Segment',inplace=True)
Additive_decomposition = sm(StoreData['Sales'], model='additive', period=12)
Additive_decomposition.trend.plot()
plt.ylabel('Segment((SEASONAL)')
plt.show()

# %%
#Extracting RESIDUAL component
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm
StoreData = pd.read_csv('/content/SuperStore-SalesDataSet (1).csv')
StoreData.columns=['Row ID',	'Order ID',	'Order Date(yyyy-mm)',	'Ship Date(yyyy-mm)',	'Ship Mode',	'Customer ID',	'Customer Name',	'Segment',	'Country',
'City',	'State',	'Postal Code',	'Region',	'Product ID',	'Category',	'Sub-Category',	'Product Name',	'Sales']
StoreData.set_index('Country',inplace=True)
Additive_decomposition = sm(StoreData['Sales'], model='additive', period=12)
Additive_decomposition.resid.plot()
plt.grid()
plt.show()
